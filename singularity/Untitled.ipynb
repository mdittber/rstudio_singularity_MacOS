# %%
install.packages('remotes')
# Out:
# Installing package into ‘/home/vagrant/R/x86_64-pc-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)

# %%
install.packages('remotes', repos = c(CRAN = 'https://cloud.r-project.org'))
# Out:
# Installing package into ‘/home/vagrant/R/x86_64-pc-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)

# %%
install.packages("dplyr")
# Out:
# Installing package into ‘/home/vagrant/R/x86_64-pc-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘pkgconfig’, ‘purrr’, ‘generics’, ‘magrittr’, ‘R6’, ‘tibble’, ‘tidyselect’

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
remotes::install_github('rstudio/renv@0.12.2')
# Out:
# Downloading GitHub repo rstudio/renv@0.12.2
#
# Running `R CMD build`...
# * checking for file ‘/tmp/RtmpsgVIFo/remotes723b4a75dca6/rstudio-renv-80e7b21/DESCRIPTION’ ... OK
# * preparing ‘renv’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Removed empty directory ‘renv/tests/testthat/resources/dummy.Rmd’
# * building ‘renv_0.12.2.tar.gz’
# Installing package into ‘/home/vagrant/R/x86_64-pc-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)

# %%
library(renv)
# Out:
# Attaching package: ‘renv’
#
#
# The following object is masked from ‘package:stats’:
#
#     update
#
#
# The following objects are masked from ‘package:utils’:
#
#     history, upgrade
#
#
# The following objects are masked from ‘package:base’:
#
#     load, remove

# %%
renv::consent(provided = TRUE)
# Out:
# * Consent to use renv has already been provided -- nothing to do.

# %%
renv::restore(prompt=FALSE)
# Out:
# The following package(s) will be updated:
#
# # CRAN ===============================
# - MASS              [7.3-53 -> 7.3-51.6]
# - R6                [2.5.0 -> 2.4.1]
# - cli               [2.2.0 -> 2.0.2]
# - digest            [0.6.27 -> 0.6.25]
# - foreign           [0.8-79 -> 0.8-80]
# - generics          [0.1.0 -> 0.0.2]
# - jsonlite          [1.7.2 -> 1.7.1]
# - magrittr          [2.0.1 -> 1.5]
# - mgcv              [1.8-33 -> 1.8-31]
# - nlme              [3.1-150 -> 3.1-148]
# - pillar            [1.4.7 -> 1.4.6]
# - renv              [rstudio/renv@0.12.2 -> 0.12.2]
# - rlang             [0.4.9 -> 0.4.7]
# - tibble            [3.0.4 -> 3.0.3]
# - vctrs             [0.3.5 -> 0.3.4]
# - BH                [* -> 1.72.0-3]
# - DBI               [* -> 1.1.0]
# - Formula           [* -> 1.2-4]
# - Hmisc             [* -> 4.4-1]
# - RColorBrewer      [* -> 1.1-2]
# - Rcpp              [* -> 1.0.5]
# - VennDiagram       [* -> 1.6.20]
# - arrow             [* -> 2.0.0]
# - askpass           [* -> 1.1]
# - backports         [* -> 1.1.10]
# - bannerCommenter   [* -> 0.1.1]
# - bit               [* -> 4.0.4]
# - bit64             [* -> 4.0.5]
# - blob              [* -> 1.2.1]
# - bookdown          [* -> 0.21]
# - broom             [* -> 0.7.0]
# - callr             [* -> 3.4.4]
# - cellranger        [* -> 1.1.0]
# - checkmate         [* -> 2.0.0]
# - clipr             [* -> 0.7.0]
# - colorspace        [* -> 1.4-1]
# - cpp11             [* -> 0.2.1]
# - curl              [* -> 4.3]
# - data.table        [* -> 1.13.2]
# - dbplyr            [* -> 1.4.4]
# - desc              [* -> 1.2.0]
# - farver            [* -> 2.0.3]
# - feather           [* -> 0.3.5]
# - forcats           [* -> 0.5.0]
# - formatR           [* -> 1.7]
# - fs                [* -> 1.5.0]
# - futile.logger     [* -> 1.4.3]
# - futile.options    [* -> 1.0.1]
# - ggplot2           [* -> 3.3.2]
# - gridExtra         [* -> 2.3]
# - gtable            [* -> 0.3.0]
# - haven             [* -> 2.3.1]
# - highr             [* -> 0.8]
# - hms               [* -> 0.5.3]
# - htmlTable         [* -> 2.1.0]
# - htmlwidgets       [* -> 1.5.2]
# - httr              [* -> 1.4.2]
# - isoband           [* -> 0.2.2]
# - jpeg              [* -> 0.1-8.1]
# - knitr             [* -> 1.30]
# - labeling          [* -> 0.3]
# - lambda.r          [* -> 1.2.4]
# - latticeExtra      [* -> 0.6-29]
# - lubridate         [* -> 1.7.9]
# - markdown          [* -> 1.1]
# - mime              [* -> 0.9]
# - mltools           [* -> 0.3.5]
# - modelr            [* -> 0.1.8]
# - munsell           [* -> 0.5.0]
# - openssl           [* -> 1.4.3]
# - pkgbuild          [* -> 1.1.0]
# - pkgload           [* -> 1.1.0]
# - plotrix           [* -> 3.7-8]
# - plyr              [* -> 1.8.6]
# - png               [* -> 0.1-7]
# - praise            [* -> 1.0.0]
# - prettyunits       [* -> 1.1.1]
# - processx          [* -> 3.4.4]
# - progress          [* -> 1.2.2]
# - ps                [* -> 1.3.4]
# - readr             [* -> 1.3.1]
# - readxl            [* -> 1.3.1]
# - rematch           [* -> 1.0.1]
# - reprex            [* -> 0.3.0]
# - rmarkdown         [* -> 2.5]
# - rprojroot         [* -> 1.3-2]
# - rstudioapi        [* -> 0.11]
# - rvest             [* -> 0.3.6]
# - scales            [* -> 1.1.1]
# - selectr           [* -> 0.4-2]
# - stringi           [* -> 1.5.3]
# - stringr           [* -> 1.4.0]
# - sys               [* -> 3.4]
# - testthat          [* -> 2.3.2]
# - tidyr             [* -> 1.1.2]
# - tidyverse         [* -> 1.3.0]
# - tinytex           [* -> 0.26]
# - viridis           [* -> 0.5.1]
# - viridisLite       [* -> 0.3.0]
# - whisker           [* -> 0.4]
# - withr             [* -> 2.3.0]
# - xfun              [* -> 0.17]
# - xml2              [* -> 1.3.2]
# - yaml              [* -> 2.2.1]
#
# Installing generics [0.0.2] ...
# 	OK [copied cache]
# Installing magrittr [1.5] ...
# 	OK [copied cache]
# Installing R6 [2.4.1] ...
# 	OK [copied cache]
# Installing renv [0.12.2] ...
# 	OK [copied local binary]
# Copying renv [0.12.2] into the cache ...
# 	OK [copied 29 files in 0.0044 seconds]
# Installing cli [2.0.2] ...
# 	OK [copied cache]
# Installing rlang [0.4.7] ...
# 	OK [copied cache]
# Installing digest [0.6.25] ...
# 	OK [copied cache]
# Installing vctrs [0.3.4] ...
# 	OK [copied cache]
# Installing pillar [1.4.6] ...
# 	OK [copied cache]
# Installing tibble [3.0.3] ...
# 	OK [copied cache]
# Installing jsonlite [1.7.1] ...
# 	OK [copied cache]
# Installing foreign [0.8-80] ...
# 	OK [copied cache]
# Installing MASS [7.3-51.6] ...
# 	OK [copied cache]
# Installing nlme [3.1-148] ...
# 	OK [copied cache]
# Installing mgcv [1.8-31] ...
# 	OK [copied cache]
# Installing BH [1.72.0-3] ...
# 	OK [copied cache]
# Installing DBI [1.1.0] ...
# 	OK [copied cache]
# Installing Formula [1.2-4] ...
# 	OK [copied cache]
# Installing png [0.1-7] ...
# 	OK [copied cache]
# Installing jpeg [0.1-8.1] ...
# 	OK [copied cache]
# Installing RColorBrewer [1.1-2] ...
# 	OK [copied cache]
# Installing latticeExtra [0.6-29] ...
# 	OK [copied cache]
# Installing gtable [0.3.0] ...
# 	OK [copied cache]
# Installing gridExtra [2.3] ...
# 	OK [copied cache]
# Installing data.table [1.13.2] ...
# 	OK [copied cache]
# Installing stringi [1.5.3] ...
# 	OK [copied cache]
# Installing stringr [1.4.0] ...
# 	OK [copied cache]
# Installing highr [0.8] ...
# 	OK [copied cache]
# Installing xfun [0.17] ...
# 	OK [copied cache]
# Installing mime [0.9] ...
# 	OK [copied cache]
# Installing markdown [1.1] ...
# 	OK [copied cache]
# Installing yaml [2.2.1] ...
# 	OK [copied cache]
# Installing knitr [1.30] ...
# 	OK [copied cache]
# Installing backports [1.1.10] ...
# 	OK [copied cache]
# Installing checkmate [2.0.0] ...
# 	OK [copied cache]
# Installing htmlwidgets [1.5.2] ...
# 	OK [copied cache]
# Installing rstudioapi [0.11] ...
# 	OK [copied cache]
# Installing htmlTable [2.1.0] ...
# 	OK [copied cache]
# Installing rprojroot [1.3-2] ...
# 	OK [copied cache]
# Installing desc [1.2.0] ...
# 	OK [copied cache]
# Installing ps [1.3.4] ...
# 	OK [copied cache]
# Installing processx [3.4.4] ...
# 	OK [copied cache]
# Installing callr [3.4.4] ...
# 	OK [copied cache]
# Installing prettyunits [1.1.1] ...
# 	OK [copied cache]
# Installing withr [2.3.0] ...
# 	OK [copied cache]
# Installing pkgbuild [1.1.0] ...
# 	OK [copied cache]
# Installing pkgload [1.1.0] ...
# 	OK [copied cache]
# Installing praise [1.0.0] ...
# 	OK [copied cache]
# Installing testthat [2.3.2] ...
# 	OK [copied cache]
# Installing isoband [0.2.2] ...
# 	OK [copied cache]
# Installing farver [2.0.3] ...
# 	OK [copied cache]
# Installing labeling [0.3] ...
# 	OK [copied cache]
# Installing colorspace [1.4-1] ...
# 	OK [copied cache]
# Installing munsell [0.5.0] ...
# 	OK [copied cache]
# Installing viridisLite [0.3.0] ...
# 	OK [copied cache]
# Installing scales [1.1.1] ...
# 	OK [copied cache]
# Installing ggplot2 [3.3.2] ...
# 	OK [copied cache]
# Installing viridis [0.5.1] ...
# 	OK [copied cache]
# Installing Hmisc [4.4-1] ...
# 	OK [copied cache]
# Installing Rcpp [1.0.5] ...
# 	OK [copied cache]
# Installing formatR [1.7] ...
# 	OK [copied cache]
# Installing lambda.r [1.2.4] ...
# 	OK [copied cache]
# Installing futile.options [1.0.1] ...
# 	OK [copied cache]
# Installing futile.logger [1.4.3] ...
# 	OK [copied cache]
# Installing VennDiagram [1.6.20] ...
# 	OK [copied cache]
# Installing bit [4.0.4] ...
# 	OK [copied cache]
# Installing bit64 [4.0.5] ...
# 	OK [copied cache]
# Installing cpp11 [0.2.1] ...
# 	OK [copied cache]
# Installing arrow [2.0.0] ...
# 	OK [copied cache]
# Installing sys [3.4] ...
# 	OK [copied cache]
# Installing askpass [1.1] ...
# 	OK [copied cache]
# Installing bannerCommenter [0.1.1] ...
# 	OK [copied cache]
# Installing blob [1.2.1] ...
# 	OK [copied cache]
# Installing tinytex [0.26] ...
# 	OK [copied cache]
# Installing rmarkdown [2.5] ...
# 	OK [copied cache]
# Installing bookdown [0.21] ...
# 	OK [copied cache]
# Installing tidyr [1.1.2] ...
# 	OK [copied cache]
# Installing broom [0.7.0] ...
# 	OK [copied cache]
# Installing rematch [1.0.1] ...
# 	OK [copied cache]
# Installing cellranger [1.1.0] ...
# 	OK [copied cache]
# Installing clipr [0.7.0] ...
# 	OK [copied cache]
# Installing curl [4.3] ...
# 	OK [copied cache]
# Installing dbplyr [1.4.4] ...
# 	OK [copied cache]
# Installing hms [0.5.3] ...
# 	OK [copied cache]
# Installing feather [0.3.5] ...
# 	OK [copied cache]
# Installing forcats [0.5.0] ...
# 	OK [copied cache]
# Installing fs [1.5.0] ...
# 	OK [copied cache]
# Installing readr [1.3.1] ...
# 	OK [copied cache]
# Installing haven [2.3.1] ...
# 	OK [copied cache]
# Installing openssl [1.4.3] ...
# 	OK [copied cache]
# Installing httr [1.4.2] ...
# 	OK [copied cache]
# Installing lubridate [1.7.9] ...
# 	OK [copied cache]
# Installing mltools [0.3.5] ...
# 	OK [copied cache]
# Installing modelr [0.1.8] ...
# 	OK [copied cache]
# Installing plotrix [3.7-8] ...
# 	OK [copied cache]
# Installing plyr [1.8.6] ...
# 	OK [copied cache]
# Installing progress [1.2.2] ...
# 	OK [copied cache]
# Installing readxl [1.3.1] ...
# 	OK [copied cache]
# Installing whisker [0.4] ...
# 	OK [copied cache]
# Installing reprex [0.3.0] ...
# 	OK [copied cache]
# Installing selectr [0.4-2] ...
# 	OK [copied cache]
# Installing xml2 [1.3.2] ...
# 	OK [copied cache]
# Installing rvest [0.3.6] ...
# 	OK [copied cache]
# Installing tidyverse [1.3.0] ...
# 	OK [copied cache]
# The dependency tree was repaired during package installation:
#        _
#   renv   [0.12.2]
#
# Call `renv::snapshot()` to capture these dependencies in the lockfile.
#
# The following package(s) have been updated:
#
# 	generics [installed version 0.0.2  != loaded version 0.1.0 ]
# 	magrittr [installed version 1.5    != loaded version 2.0.1 ]
# 	R6       [installed version 2.4.1  != loaded version 2.5.0 ]
# 	rlang    [installed version 0.4.7  != loaded version 0.4.9 ]
# 	digest   [installed version 0.6.25 != loaded version 0.6.27]
# 	vctrs    [installed version 0.3.4  != loaded version 0.3.5 ]
# 	pillar   [installed version 1.4.6  != loaded version 1.4.7 ]
# 	tibble   [installed version 3.0.3  != loaded version 3.0.4 ]
# 	jsonlite [installed version 1.7.1  != loaded version 1.7.2 ]
#
# Consider restarting the R session and loading the newly-installed packages.
